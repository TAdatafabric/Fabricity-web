# %% [markdown]
# 1). Import Library

# %%
import pandas as pd #dataframe library
import numpy as np #numeric library
import datetime as dt

#plot library
import matplotlib.pyplot as plt 
import seaborn as sns 

#evaluation library
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report,recall_score,precision_score

#label encoder library
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# for min_max scaling (Kaggle)
from mlxtend.preprocessing import minmax_scaling

from sklearn.preprocessing import MinMaxScaler, StandardScaler

# for changing datatime type
from sklearn.preprocessing import StandardScaler

# for Box-Cox Transformation
from scipy import stats

# set seed for reproducibility
np.random.seed(0)

# %% [markdown]
# 2). Load Dataset

# %%
training_url = "https://docs.google.com/spreadsheets/d/1Lii15km8Q91IWQKrhY6I0f92ZR2o4st7/edit#gid=560237263"
training_dataset = training_url.replace('/edit#gid=', '/export?format=csv&gid=')

# %%
data = pd.read_csv(training_dataset)
# Out:
# C:\Users\Kayla\AppData\Local\Temp\ipykernel_14380\8510265.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(training_dataset)

# %% [markdown]
# 3). Make a copy

# %%
data = data.copy()

# %% [markdown]
# 4). Dropping Un-needed Column

# %%
data = data.drop(['subs_key', 'b_no','event_action_code', 'destination_poc'], axis = 1)

# %% [markdown]
# 5). Preprocessing (Change order and name)

# %%
print(data.columns)
# Out:
# Index(['day_no', 'time_no', 'service_filter', 'payment_cat', 'subs_no',
#        'prefix_dom_sk_id', 'originating_cell_id', 'home_poc', 'city_name',
#        'physical_poc', 'roam_zone', 'rem_bal', 'rtd_amt', 'free_unit',
#        'usg_unit', 'sid'],
#       dtype='object')

# %%
col_name = [
    'date',
    'date_time',
    'service_type',
    'payment_type',
    'subs_id',
    'prefix_domain',
    'cell_id',
    'home_poc',
    'city_name',
    'physical_poc',
    'roam_zone',
    'remaining_balance',
    'amount_of_trx',
    'free_unit',
    'usage_unit',
    'sid'
]

data.columns = col_name
print(data.columns)
# Out:
# Index(['date', 'date_time', 'service_type', 'payment_type', 'subs_id',
#        'prefix_domain', 'cell_id', 'home_poc', 'city_name', 'physical_poc',
#        'roam_zone', 'remaining_balance', 'amount_of_trx', 'free_unit',
#        'usage_unit', 'sid'],
#       dtype='object')

# %%
order = [
    'date',
    'date_time',
    'service_type',
    'payment_type',
    'subs_id',
    'prefix_domain',
    'cell_id',
    'home_poc',
    'city_name',
    'physical_poc',
    'roam_zone',
    #'destination_poc',
    'sid',
    'remaining_balance',
    'amount_of_trx',
    'free_unit',
    'usage_unit'
]

data = data[order]

# %%
data.head()
# Out:
#        date       date_time service_type payment_type     subs_id
# 0  1/9/2021  1/9/2021 21:24       SMSBAS          PRE  2106705274  \
# 1  1/9/2021  1/9/2021 21:29       SMSBAS          PRE  2106705274
# 2  1/9/2021  1/9/2021 21:36       SMSBAS          PRE  2106705274
# 3  1/9/2021   1/9/2021 7:43       VASOCC          PRE  1075588229
# 4  1/9/2021   1/9/2021 4:24       CONTEN          PRE  1075588229
#
#    prefix_domain             cell_id home_poc city_name physical_poc
# 0           5636  510.11.34314.18692      JK0   JAKARTA          KA0  \
# 1           5636  510.11.34314.38401      JK0   JAKARTA          KA0
# 2           5636  510.11.34314.18693      JK0   JAKARTA          KA0
# 3             -1             0.0.0.0    NOPOC   JAKARTA            B
# 4             -1     510.11.411042.3      JK0   JAKARTA          JK0
#
#   roam_zone     sid remaining_balance  amount_of_trx  free_unit  usage_unit
# 0    LOCXLM  SILVER               673             50        0.0           1
# 1    LOCXLM  SILVER               623             50        0.0           1
# 2    LOCXLM  SILVER               573             50        0.0           1
# 3    LOCXLM  SILVER              7220           5500        0.0           1
# 4    NATZ10   TRIBE            101720             55        NaN     1048576

# %% [markdown]
# 5.2). Missing Values

# %%
missing_values_count = data.isnull().sum() + data.isin(['', ' ','00000000', None, np.nan]).sum()
missing_values_count
# Out:
# date                     0
# date_time                0
# service_type             0
# payment_type             0
# subs_id                  0
# prefix_domain            0
# cell_id                  0
# home_poc                 0
# city_name                0
# physical_poc             0
# roam_zone                0
# sid                      0
# remaining_balance        0
# amount_of_trx            0
# free_unit            29292
# usage_unit               0
# dtype: int64

# %%
data = data.fillna(0)
data = data.replace(['', ' ', None], 0)

# %%
missing_values_count = data.isnull().sum() + data.isin(['', ' ', None]).sum()
missing_values_count
# Out:
# date                 0
# date_time            0
# service_type         0
# payment_type         0
# subs_id              0
# prefix_domain        0
# cell_id              0
# home_poc             0
# city_name            0
# physical_poc         0
# roam_zone            0
# sid                  0
# remaining_balance    0
# amount_of_trx        0
# free_unit            0
# usage_unit           0
# dtype: int64

# %% [markdown]
# 6). Data type conversion for numerical

# %%
data[['remaining_balance', 'amount_of_trx', 'free_unit', 'usage_unit']].dtypes
# Out:
# remaining_balance     object
# amount_of_trx          int64
# free_unit            float64
# usage_unit             int64
# dtype: object

# %%
def non_numeric(x):
    non_numeric_data = pd.DataFrame(data[data[x].astype(str).str.contains('[^0-9.-]')])
    return non_numeric_data

# %%
non_numeric('remaining_balance')
# Out:
#           date       date_time service_type payment_type    subs_id
# 1108  8/9/2021  8/9/2021 14:36       CONTEN          PRE  545592898  \
# 1109  8/9/2021  8/9/2021 14:36       CONTEN          PRE  545592898
# 1110  8/9/2021  8/9/2021 14:36       CONTEN          PRE  545592898
# 1111  8/9/2021  8/9/2021 14:36       CONTEN          PRE  545592898
# 1112  8/9/2021  8/9/2021 14:36       CONTEN          PRE  545592898
# 1113  8/9/2021  8/9/2021 14:36       CONTEN          PRE  545592898
#
#       prefix_domain          cell_id home_poc city_name physical_poc
# 1108             -1  510.11.220267.9      BD0   BANDUNG          MD0  \
# 1109             -1  510.11.220267.9      BD0   BANDUNG          MD0
# 1110             -1  510.11.220267.9      BD0   BANDUNG          MD0
# 1111             -1  510.11.220267.9      BD0   BANDUNG          MD0
# 1112             -1  510.11.220267.9      BD0   BANDUNG          MD0
# 1113             -1  510.11.220267.9      BD0   BANDUNG          MD0
#
#      roam_zone       sid remaining_balance  amount_of_trx  free_unit
# 1108    NATZ10  CATCHALL        2425:06:00             35        0.0  \
# 1109    NATZ10    VOLDUO        2423:06:00              2        0.0
# 1110    NATZ10   VOLVIKI        2421:06:00              2        0.0
# 1111    NATZ10     VOLIG        2419:06:00              2        0.0
# 1112    NATZ10   NETWORK        2417:06:00              2        0.0
# 1113    NATZ10  VOLMFISH        2415:06:00              2        0.0
#
#       usage_unit
# 1108     3993600
# 1109      102400
# 1110      102400
# 1111      102400
# 1112      102400
# 1113      102400

# %%
def non_numeric(x):
    non_numeric_mask = data[x].astype(str).str.contains('[^0-9.-]')
    data.drop(data[non_numeric_mask].index, inplace=True)
    return data

non_numeric('remaining_balance')
# Out:
#             date       date_time service_type payment_type     subs_id
# 0       1/9/2021  1/9/2021 21:24       SMSBAS          PRE  2106705274  \
# 1       1/9/2021  1/9/2021 21:29       SMSBAS          PRE  2106705274
# 2       1/9/2021  1/9/2021 21:36       SMSBAS          PRE  2106705274
# 3       1/9/2021   1/9/2021 7:43       VASOCC          PRE  1075588229
# 4       1/9/2021   1/9/2021 4:24       CONTEN          PRE  1075588229
# ...          ...             ...          ...          ...         ...
# 43942  30/4/2022   4/30/22 18:22       NATNAL          PRE   712325998
# 43943  30/4/2022    4/30/22 7:49       NATNAL          PRE   712325998
# 43944  30/4/2022   4/30/22 20:39       CONTEN          PRE  1182349800
# 43945  30/4/2022   4/30/22 11:27       CONTEN          PRE  1182349800
# 43946  30/4/2022   4/30/22 22:27       NATNAL          PRE   767791937
#
#        prefix_domain             cell_id home_poc           city_name
# 0               5636  510.11.34314.18692      JK0             JAKARTA  \
# 1               5636  510.11.34314.38401      JK0             JAKARTA
# 2               5636  510.11.34314.18693      JK0             JAKARTA
# 3                 -1             0.0.0.0    NOPOC             JAKARTA
# 4                 -1     510.11.411042.3      JK0             JAKARTA
# ...              ...                 ...      ...                 ...
# 43942           3207  510.11.25190.31588      JK0             JAKARTA
# 43943           3207  510.11.25190.31588      JK0             JAKARTA
# 43944             -1     510.11.540155.1      JK0             JAKARTA
# 43945             -1     510.11.540155.1      JK0             JAKARTA
# 43946           3207  510.11.25190.36365      MD2  TEBING TINGGI DELI
#
#       physical_poc roam_zone         sid remaining_balance  amount_of_trx
# 0              KA0    LOCXLM      SILVER               673             50  \
# 1              KA0    LOCXLM      SILVER               623             50
# 2              KA0    LOCXLM      SILVER               573             50
# 3                B    LOCXLM      SILVER              7220           5500
# 4              JK0    NATZ10       TRIBE            101720             55
# ...            ...       ...         ...               ...            ...
# 43942          BD6    NGBXLM      SILVER            2206.0           3950
# 43943          BD6    NGBXLM      SILVER            6788.0            346
# 43944          SB0    NATZ10  VOLYOUTUBE            1567.0            668
# 43945          SB0    NATZ10  VOLYOUTUBE            5415.0              6
# 43946          BD6    FARXLM      SILVER           23153.0            800
#
#        free_unit  usage_unit
# 0            0.0           1
# 1            0.0           1
# 2            0.0           1
# 3            0.0           1
# 4            0.0     1048576
# ...          ...         ...
# 43942        0.0        2460
# 43943        0.0         470
# 43944        0.0    34201600
# 43945        0.0      307200
# 43946        0.0         800
#
# [43941 rows x 16 columns]

# %%
#non_numeric('remaining_balance')

def non_numeric(x):
    non_numeric_data = pd.DataFrame(data[data[x].astype(str).str.contains('[^0-9.-]')])
    return non_numeric_data

# %%
non_numeric('amount_of_trx')
# Out:
# Empty DataFrame
# Columns: [date, date_time, service_type, payment_type, subs_id, prefix_domain, cell_id, home_poc, city_name, physical_poc, roam_zone, sid, remaining_balance, amount_of_trx, free_unit, usage_unit]
# Index: []

# %%
non_numeric('free_unit')
# Out:
# Empty DataFrame
# Columns: [date, date_time, service_type, payment_type, subs_id, prefix_domain, cell_id, home_poc, city_name, physical_poc, roam_zone, sid, remaining_balance, amount_of_trx, free_unit, usage_unit]
# Index: []

# %%
non_numeric('usage_unit')
# Out:
# Empty DataFrame
# Columns: [date, date_time, service_type, payment_type, subs_id, prefix_domain, cell_id, home_poc, city_name, physical_poc, roam_zone, sid, remaining_balance, amount_of_trx, free_unit, usage_unit]
# Index: []

# %%
# show data types from each column
print(data.dtypes)
# Out:
# date                  object
# date_time             object
# service_type          object
# payment_type          object
# subs_id                int64
# prefix_domain          int64
# cell_id               object
# home_poc              object
# city_name             object
# physical_poc          object
# roam_zone             object
# sid                   object
# remaining_balance     object
# amount_of_trx          int64
# free_unit            float64
# usage_unit             int64
# dtype: object

# %%
data['amount_of_trx'] = data['amount_of_trx'].astype(float)
data['remaining_balance'] = data['remaining_balance'].astype(float)
data['usage_unit'] = data['usage_unit'].astype(float)

# %%
# show data types from each column
print(data.dtypes)
# Out:
# date                  object
# date_time             object
# service_type          object
# payment_type          object
# subs_id                int64
# prefix_domain          int64
# cell_id               object
# home_poc              object
# city_name             object
# physical_poc          object
# roam_zone             object
# sid                   object
# remaining_balance    float64
# amount_of_trx        float64
# free_unit            float64
# usage_unit           float64
# dtype: object

# %% [markdown]
# 7). Split Time from 'data_time' cloumn

# %%
print(data.dtypes)
# Out:
# date                  object
# date_time             object
# service_type          object
# payment_type          object
# subs_id                int64
# prefix_domain          int64
# cell_id               object
# home_poc              object
# city_name             object
# physical_poc          object
# roam_zone             object
# sid                   object
# remaining_balance    float64
# amount_of_trx        float64
# free_unit            float64
# usage_unit           float64
# dtype: object

# %%
#drop the date column
data = data.drop('date', axis=1)
